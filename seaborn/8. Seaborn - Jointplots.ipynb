# %% [markdown]
# # Jointplot
#
# It creates a multi-panel figure that shows both bivariate relationship between two variables along with the univariate distribution of eacch on separate axes.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',kind='hex',data=tips)

# %% [markdown]
# ### Hex is 2d histogram. if it is denser, it will create darker plot.

# %%
sns.jointplot(x='total_bill',y='tip',kind='kde',data=tips)

# %% [markdown]
# ## Regressoion plot

# %%
sns.jointplot(x='total_bill',y='tip',kind='reg',data=tips)
